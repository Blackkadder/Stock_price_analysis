# %%
import pandas as pd
import json
import quandl

# %%
API = json.load(open("C:/APIs/APIs.txt"))

# %%
quandl.ApiConfig.api_key = API['quandl']

# %%
watchlist = ['AAPL','GOOG','TSLA','EXPR','LUV','DATA','CAT','NFLX','NVDA','AMD',
             'SQ','AMZN']

# %%
df = quandl.get_table('WIKI/PRICES', ticker=watchlist, paginate = True)

# %%
df
# Out:
#       ticker       date    open      high     low   close     volume  \
# None
# 0       AAPL 1980-12-12   28.75   28.8700   28.75   28.75  2093900.0
# 1       AAPL 1980-12-15   27.38   27.3800   27.25   27.25   785200.0
# 2       AAPL 1980-12-16   25.37   25.3700   25.25   25.25   472000.0
# 3       AAPL 1980-12-17   25.87   26.0000   25.87   25.87   385900.0
# 4       AAPL 1980-12-18   26.63   26.7500   26.63   26.63   327900.0
# 5       AAPL 1980-12-19   28.25   28.3800   28.25   28.25   217100.0
# 6       AAPL 1980-12-22   29.63   29.7500   29.63   29.63   166800.0
# 7       AAPL 1980-12-23   30.88   31.0000   30.88   30.88   209600.0
# 8       AAPL 1980-12-24   32.50   32.6300   32.50   32.50   214300.0
# 9       AAPL 1980-12-26   35.50   35.6200   35.50   35.50   248100.0
# 10      AAPL 1980-12-29   36.00   36.1300   36.00   36.00   415900.0
# 11      AAPL 1980-12-30   35.25   35.2500   35.12   35.12   307500.0
# ...

# %%
df['ticker'].unique()
# Out:
# array(['AAPL', 'AMD', 'AMZN', 'CAT', 'DATA', 'EXPR', 'GOOG', 'LUV', 'NFLX',
#        'NVDA', 'TSLA'], dtype=object)

# %%
#df.to_csv('C:/Stock data/data.csv')
